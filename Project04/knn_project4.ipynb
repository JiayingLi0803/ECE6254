# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
from sklearn.model_selection import train_test_split

np.random.seed(2017) # Set random seed so results are repeatable

# %% [markdown]
# # N = 100

# %%
n = 100 # number of training points
## Generate a simple 2D dataset
X, y = datasets.make_moons(n, shuffle = True, noise = 0.3)

# %%
train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.25, random_state=2017)
train_score, test_score = [], []
for k in range(1, round(n/2)):
    knnClassifier = neighbors.KNeighborsClassifier(k, weights = 'uniform')
    knnClassifier.fit(train_x, train_y)
    train_score.append(knnClassifier.score(train_x,train_y))
    test_score.append(knnClassifier.score(test_x,test_y))
plt.plot(list(range(1,round(n/2))), train_score, c = "red", label = "train score")
plt.plot(list(range(1,round(n/2))), test_score, c = "blue", label = "test score")
plt.legend()
print("K for Largest Test Score: ", test_score.index(max(test_score))+1)
# Out:
# K for Largest Test Score:  2

# %%
k = 2 # number of neighbors to consider 

## Create instance of KNN classifier
classifier = neighbors.KNeighborsClassifier(k, weights = 'uniform')
classifier.fit(X, y)

## Plot the decision boundary. 
# Begin by creating the mesh [x_min, x_max]x[y_min, y_max].
h = .02  # step size in the mesh
x_delta = (X[:, 0].max() - X[:, 0].min())*0.05 # add 5% white space to border
y_delta = (X[:, 1].max() - X[:, 1].min())*0.05
x_min, x_max = X[:, 0].min() - x_delta, X[:, 0].max() + x_delta
y_min, y_max = X[:, 1].min() - y_delta, X[:, 1].max() + y_delta
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = classifier.predict(np.c_[xx.ravel(), yy.ravel()])

# Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00'])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

## Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("%i-NN classifier trained on %i data points" % (k,n))

## Show the plot
plt.show()

# %% [markdown]
# # N = 500

# %%
n = 500 # number of training points
## Generate a simple 2D dataset
X, y = datasets.make_moons(n, shuffle = True, noise = 0.3)

# %%
train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.25, random_state=2017)
train_score, test_score = [], []
for k in range(1, round(2*np.sqrt(n))):
    knnClassifier = neighbors.KNeighborsClassifier(k, weights = 'uniform')
    knnClassifier.fit(train_x, train_y)
    train_score.append(knnClassifier.score(train_x,train_y))
    test_score.append(knnClassifier.score(test_x,test_y))
plt.plot(list(range(1,round(2*np.sqrt(n)))), train_score, c = "red", label = "train score")
plt.plot(list(range(1,round(2*np.sqrt(n)))), test_score, c = "blue", label = "test score")
plt.legend()
print("K for Largest Test Score: ", test_score.index(max(test_score))+1)
# Out:
# K for Largest Test Score:  19

# %%
k = 19 # number of neighbors to consider 

## Create instance of KNN classifier
classifier = neighbors.KNeighborsClassifier(k, weights = 'uniform')
classifier.fit(X, y)

## Plot the decision boundary. 
# Begin by creating the mesh [x_min, x_max]x[y_min, y_max].
h = .02  # step size in the mesh
x_delta = (X[:, 0].max() - X[:, 0].min())*0.05 # add 5% white space to border
y_delta = (X[:, 1].max() - X[:, 1].min())*0.05
x_min, x_max = X[:, 0].min() - x_delta, X[:, 0].max() + x_delta
y_min, y_max = X[:, 1].min() - y_delta, X[:, 1].max() + y_delta
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = classifier.predict(np.c_[xx.ravel(), yy.ravel()])

# Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00'])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

## Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("%i-NN classifier trained on %i data points" % (k,n))

## Show the plot
plt.show()

# %% [markdown]
# # N = 1000

# %%
n = 1000 # number of training points
## Generate a simple 2D dataset
X, y = datasets.make_moons(n, shuffle = True, noise = 0.3)

# %%
train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.25, random_state=2017)
train_score, test_score = [], []
for k in range(1, round(2*np.sqrt(n))):
    knnClassifier = neighbors.KNeighborsClassifier(k, weights = 'uniform')
    knnClassifier.fit(train_x, train_y)
    train_score.append(knnClassifier.score(train_x,train_y))
    test_score.append(knnClassifier.score(test_x,test_y))
plt.plot(list(range(1,round(2*np.sqrt(n)))), train_score, c = "red", label = "train score")
plt.plot(list(range(1,round(2*np.sqrt(n)))), test_score, c = "blue", label = "test score")
plt.legend()
print("K for Largest Test Score: ", test_score.index(max(test_score))+1)
# Out:
# K for Largest Test Score:  5

# %%
k = 5 # number of neighbors to consider 

## Create instance of KNN classifier
classifier = neighbors.KNeighborsClassifier(k, weights = 'uniform')
classifier.fit(X, y)

## Plot the decision boundary. 
# Begin by creating the mesh [x_min, x_max]x[y_min, y_max].
h = .02  # step size in the mesh
x_delta = (X[:, 0].max() - X[:, 0].min())*0.05 # add 5% white space to border
y_delta = (X[:, 1].max() - X[:, 1].min())*0.05
x_min, x_max = X[:, 0].min() - x_delta, X[:, 0].max() + x_delta
y_min, y_max = X[:, 1].min() - y_delta, X[:, 1].max() + y_delta
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = classifier.predict(np.c_[xx.ravel(), yy.ravel()])

# Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00'])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

## Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("%i-NN classifier trained on %i data points" % (k,n))

## Show the plot
plt.show()

# %% [markdown]
# # N = 5000

# %%
n = 5000 # number of training points
## Generate a simple 2D dataset
X, y = datasets.make_moons(n, shuffle = True, noise = 0.3)

# %%
train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.25, random_state=2017)
train_score, test_score = [], []
for k in range(1, round(2*np.sqrt(n))):
    knnClassifier = neighbors.KNeighborsClassifier(k, weights = 'uniform')
    knnClassifier.fit(train_x, train_y)
    train_score.append(knnClassifier.score(train_x,train_y))
    test_score.append(knnClassifier.score(test_x,test_y))
plt.plot(list(range(1,round(2*np.sqrt(n)))), train_score, c = "red", label = "train score")
plt.plot(list(range(1,round(2*np.sqrt(n)))), test_score, c = "blue", label = "test score")
plt.legend()
print("K for Largest Test Score: ", test_score.index(max(test_score))+1)
# Out:
# K for Largest Test Score:  60

# %%
k = 60 # number of neighbors to consider 

## Create instance of KNN classifier
classifier = neighbors.KNeighborsClassifier(k, weights = 'uniform')
classifier.fit(X, y)

## Plot the decision boundary. 
# Begin by creating the mesh [x_min, x_max]x[y_min, y_max].
h = .02  # step size in the mesh
x_delta = (X[:, 0].max() - X[:, 0].min())*0.05 # add 5% white space to border
y_delta = (X[:, 1].max() - X[:, 1].min())*0.05
x_min, x_max = X[:, 0].min() - x_delta, X[:, 0].max() + x_delta
y_min, y_max = X[:, 1].min() - y_delta, X[:, 1].max() + y_delta
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = classifier.predict(np.c_[xx.ravel(), yy.ravel()])

# Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00'])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

## Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("%i-NN classifier trained on %i data points" % (k,n))

## Show the plot
plt.show()
